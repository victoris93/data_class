# %% [markdown]
# # Exercise: Have a look at the electrophysiology data using Pandas

# %%
import pandas as pd

# Set some Pandas options: maximum number of rows/columns it's going to display
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # Load electrophysiology data

# %%
df = pd.read_csv('../../data/QC_passed_2024-07-04_collected.csv', index_col=0)

# %% [markdown]
# ## 1. How many rows/columns does the data set have?

# %%
df.shape
# Out:
# (827, 35)

# %% [markdown]
# ## 2. Display the first 5 rows of the DataFrame

# %%
df.head()
# Out:
#        area tissue_source        OP patcher  patient_age      filename slice  \
# 0  temporal     Bielefeld  OP230420   Verji           13  23420003.abf    S1
# 1  temporal     Bielefeld  OP230420   Verji           13  23420003.abf    S1
# 2  temporal     Bielefeld  OP230420   Verji           13  23420003.abf    S1
# 3  temporal     Bielefeld  OP230420   Verji           13  23420003.abf    S1
# 4  temporal     Bielefeld  OP230420   Verji           13  23420003.abf    S1
#
#    cell_ch    cell_ID day treatment  hrs_incubation repatch  hrs_after_OP  \
# 0        1  23420S1c1  D1       TTX             0.0      no     10.416389
# 1        3  23420S1c3  D1       TTX             0.0      no     10.416389
# 2        6  23420S1c6  D1       TTX             0.0      no     10.416389
# 3        7  23420S1c7  D1       TTX             0.0     yes     10.416389
# 4        8  23420S1c8  D1       TTX             0.0     yes     10.416389
#
#          Rs        Rin  resting_potential  max_spikes  Rheobase  AP_heigth  \
# 0  6.675643  39.025301         -74.285889          24     200.0  80.749512
# 1  7.867174  48.728367         -69.573975          26     300.0  78.448486
# 2  8.820134  35.971082         -54.956055          22     300.0  76.660156
# 3  7.269195  39.186101         -69.268799          24     300.0  75.030518
# 4  6.000400  31.599917         -70.550537          22     350.0  81.011963
#
#           TH   max_depol  max_repol  membra_time_constant_tau  capacitance  \
# 0 -35.278320  336.181641 -60.791016                     19.40   510.601767
# 1 -32.043457  350.097656 -67.138672                     17.30   393.397918
# 2 -29.827881  270.629883 -52.246094                     14.85   426.098774
# 3 -29.699707  242.553711 -71.411133                     17.15   478.273362
# 4 -33.068848  309.448242 -61.401367                     16.65   575.513924
#
#   comments   rheo_ramp  AP_halfwidth  Rheobse_ramp  Unnamed: 27  rheos_ramp  \
# 0        0  753.380113      1.151009           NaN          NaN         NaN
# 1        1  585.102837      1.006321           NaN          NaN         NaN
# 2        3  173.915797      1.266335           NaN          NaN         NaN
# 3        4  598.079936      0.994396           NaN          NaN         NaN
# 4        5  786.927898      1.182830           NaN          NaN         NaN
#
#   comment     high K concentration  RMP_from_char
# 0     NaN NaN                 8 mM     -61.828554
# 1     NaN NaN                 8 mM     -60.460298
# 2     NaN NaN                 8 mM     -59.615979
# 3     NaN NaN                 8 mM     -61.173839
# 4     NaN NaN                 8 mM     -60.956350

# %% [markdown]
# ## 3. Display the names and dtypes of all the columns

# %%
df.dtypes
# Out:
# area                         object
# tissue_source                object
# OP                           object
# patcher                      object
# patient_age                   int64
# filename                     object
# slice                        object
# cell_ch                       int64
# cell_ID                      object
# day                          object
# treatment                    object
# hrs_incubation              float64
# repatch                      object
# hrs_after_OP                float64
# Rs                          float64
# Rin                         float64
# resting_potential           float64
# max_spikes                    int64
# Rheobase                    float64
# AP_heigth                   float64
# TH                          float64
# max_depol                   float64
# max_repol                   float64
# membra_time_constant_tau    float64
# capacitance                 float64
# comments                     object
# rheo_ramp                   float64
# AP_halfwidth                float64
# Rheobse_ramp                float64
# Unnamed: 27                 float64
# rheos_ramp                  float64
# comment                      object
#                             float64
# high K concentration         object
# RMP_from_char               float64
# dtype: object

# %% [markdown]
# ## 4. Display the unique values of the `high K concentration` and of the `treatment` columns

# %%
df['high K concentration'].unique()
# Out:
# array(['8 mM', '15 mM'], dtype=object)

# %%
df['treatment'].unique()
# Out:
# array(['TTX', 'high K', 'Ctrl', 'wash in high K'], dtype=object)

# %% [markdown]
# ## 5. Display the main statistics of the `max_spikes` column

# %%
df['max_spikes'].describe()
# Out:
# count     827.000000
# mean       27.920193
# std        57.997378
# min         0.000000
# 25%        19.000000
# 50%        26.000000
# 75%        33.000000
# max      1664.000000
# Name: max_spikes, dtype: float64

# %% [markdown]
# ## 6. Show all the rows where the max number of spikes is larger than 50

# %%
df.loc[df['max_spikes'] > 50]
# Out:
#          area tissue_source        OP patcher  patient_age      filename  \
# 131  temporal     Bielefeld  OP231130   Verji           39  23n30003.abf
# 138  temporal     Bielefeld  OP231130   Verji           39  23n30037.abf
# 401  temporal       Hamburg  OP230808   Verji           14  23808003.abf
# 483  temporal     Bielefeld  OP230209   Verji           63  23209012.abf
# 579  temporal         Mitte  OP230810   Verji           63  23810004.abf
# 581  temporal         Mitte  OP230810   Verji           63  23810004.abf
# 582  temporal         Mitte  OP230810   Verji           63  23810004.abf
# 795  temporal       Virchow  OP230314   Verji           12  23314003.abf
# 889  temporal       Hamburg  OP240117   Verji           55  24118004.abf
# 890  temporal       Hamburg  OP240117   Verji           55  24118004.abf
#
#      slice  cell_ch       cell_ID day       treatment  hrs_incubation repatch  \
# 131     S1        1     23n30S1c1  D1            Ctrl             0.0     yes
# 138  S1_D2        2  23n30S1_D2c2  D2  wash in high K            21.0      no
# 401     S1        6     23808S1c6  D1             TTX             0.0      no
# 483     S2        5     23209S2c5  D1          high K             0.0      no
# 579     S1        5     23810S1c5  D1          high K             0.0     yes
# 581     S1        7     23810S1c7  D1          high K             0.0     yes
# 582     S1        8     23810S1c8  D1          high K             0.0      no
# 795     S1        8     23314S1c8  D1          high K             0.0      no
# 889  S2_D2        4  24117S2_D2c4  D1            Ctrl            20.0      no
# 890  S2_D2        5  24117S2_D2c5  D1            Ctrl            20.0      no
#
#      hrs_after_OP         Rs         Rin  resting_potential  max_spikes  \
# 131     11.992778  15.627081   58.666581         -78.060913          55
# 138     32.699444   7.426442   65.804793         -67.544556          61
# 401      8.163333  10.394754  106.082649         -83.300781        1664
# 483     -2.874722   8.525730   81.231493         -69.049072          53
# 579      5.660833  25.468412   79.043216         -65.155029          55
# 581      5.660833  26.756530   74.709503         -64.855957          53
# 582      5.660833  18.023665   63.532613         -61.413574          55
# 795      5.940833  22.054204   97.596130         -67.358398          52
# 889     26.424200  17.188385  139.095453         -76.916504          61
# 890     26.424200  27.929918  140.091217         -70.422363          56
#
#      Rheobase  AP_heigth         TH   max_depol   max_repol  \
# 131     300.0  88.775635 -41.577148  352.294922 -103.515625
# 138     250.0  77.716064 -36.505127  246.459961  -74.340820
# 401    -300.0  71.081543 -15.057373  237.426758  -69.702148
# 483     100.0  82.275391 -34.912109  365.478516  -98.266602
# 579     100.0  85.491943 -43.072510  389.770508  -80.078125
# 581     150.0  90.942383 -42.932129  423.950195  -83.007812
# 582     200.0  84.509277 -39.605713  339.843750  -77.392578
# 795     100.0  79.431152 -41.333008  325.073242 -111.572266
# 889     100.0  78.436279 -40.686035  316.040039  -95.092773
# 890     100.0  82.684326 -44.421387  325.561523  -96.923828
#
#      membra_time_constant_tau  capacitance                 comments  \
# 131                     13.80   329.350619                        0
# 138                     12.50   200.293398  8; exclude; Rs_end > 30
# 401                     13.05    98.940861                        5
# 483                     13.05   141.831642                        8
# 579                     11.45   241.592788                        3
# 581                      9.10   239.316854                        5
# 582                      7.10   146.691551                        6
# 795                     13.30   186.404790                        5
# 889                     19.80   201.367598                        3
# 890                     18.85   226.172391                        4
#
#       rheo_ramp  AP_halfwidth  Rheobse_ramp  Unnamed: 27  rheos_ramp comment  \
# 131         NaN      0.811086    351.581719          NaN         NaN     NaN
# 138         NaN      0.950158    322.090736          NaN         NaN     NaN
# 401         NaN      1.025354           NaN          NaN         NaN     NaN
# 483  192.024601      0.713136           NaN          NaN         NaN     NaN
# 579  224.587500      0.966593           NaN          NaN         NaN     NaN
# 581  307.540300      0.965371           NaN          NaN         NaN     NaN
# 582  199.506700      1.043352           NaN          NaN         NaN     NaN
# 795         NaN      0.776089           NaN          NaN  201.505075     NaN
# 889         NaN      0.740537    295.539851          NaN         NaN     NaN
# 890         NaN      0.769121    207.006900          NaN         NaN     NaN
#
#         high K concentration  RMP_from_char
# 131 NaN                 8 mM     -71.584465
# 138 NaN                 8 mM     -59.579331
# 401 NaN                 8 mM     -32.684415
# 483 NaN                 8 mM     -58.246034
# 579 NaN                 8 mM     -60.860893
# 581 NaN                 8 mM     -61.513494
# 582 NaN                 8 mM     -62.291177
# 795 NaN                 8 mM     -61.035575
# 889 NaN                 8 mM     -59.561161
# 890 NaN                 8 mM     -60.495223

# %% [markdown]
# ## 7. Do the same of part 6, for the rows where `high K concentration` is `8 mM` and `15 mM`
#
# Is the distribution any different?

# %%
df.loc[df['high K concentration'] == '8 mM', 'max_spikes'].describe()
# Out:
# count     474.000000
# mean       30.955696
# std        75.960740
# min         1.000000
# 25%        21.000000
# 50%        27.000000
# 75%        34.000000
# max      1664.000000
# Name: max_spikes, dtype: float64

# %%
df.loc[df['high K concentration'] == '15 mM', 'max_spikes'].describe()
# Out:
# count    353.000000
# mean      23.844193
# std       10.519791
# min        0.000000
# 25%       18.000000
# 50%       24.000000
# 75%       31.000000
# max       48.000000
# Name: max_spikes, dtype: float64

# %% [markdown]
# ## 8. Display the statistics of `max_spikes` when `high K concentration` is `8 mM`, and the maximum number of spikes is <= 100
#
# Does that change your conclusion?

# %%
df.loc[(df['high K concentration'] == '8 mM') & (df['max_spikes'] <= 100), 'max_spikes'].describe()
# Out:
# count    473.000000
# mean      27.503171
# std       10.965493
# min        1.000000
# 25%       21.000000
# 50%       27.000000
# 75%       34.000000
# max       61.000000
# Name: max_spikes, dtype: float64

# %% [markdown]
# ## 9. Add a new column with an "anonymized" patcher name
#
# Add a new column, `patcher_id`, composed of the first and last uppercase letters of the patcher's name.
#
# Display all the unique `patcher_id` values

# %%
patcher_upper = df['patcher'].str.upper()
df['patcher_id'] = patcher_upper.str[0] + patcher_upper.str[-1]

# %%
df['patcher_id'].unique()
# Out:
# array(['VI', 'RE'], dtype=object)
