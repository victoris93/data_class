# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
n = np.arange(10, 1e8, 1e3)

# %%
speeddown = (10*n*np.log(10*n)) / (n*np.log(n))

# %%
speeddown
# Out:
# array([20.        , 13.32853871, 13.02737101, ..., 11.25000203,
#        11.25000135, 11.25000067])

# %%
plt.plot(n, speeddown)

# %%
speeddown = (np.log(10*n)) / (np.log(n))
plt.plot(n, speeddown)

# %%
plt.plot(n, np.log(n))

# %%
speeddown
# Out:
# array([2.        , 1.33285387, 1.3027371 , ..., 1.1250002 , 1.12500014,
#        1.12500007])

# %%
np.log10(10)
# Out:
# 1.0
